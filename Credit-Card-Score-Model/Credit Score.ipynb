# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/train.csv')
df.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
# 3            809.98                31.377862  22 Years and 4 Months
# 4            809.98                24.797347  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949             80.41529544
# 1                     No           49.574949             118.2802216
# 2                     No           49.574949             81.69952126
# 3                     No           49.574949             199.4580744
# 4                     No           49.574949             41.42015309
#
#                   Payment_Behaviour Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments     312.4940887         Good
# 1    Low_spent_Large_value_payments     284.6291625         Good
# 2   Low_spent_Medium_value_payments     331.2098629         Good
# 3    Low_spent_Small_value_payments     223.4513097         Good
# 4  High_spent_Medium_value_payments      341.489231         Good
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (26097, 28)

# %%
df.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           22174.000000       26097.000000     26097.000000
# mean             4226.596994          16.547496        23.338085
# std              3183.481913         113.894741       131.995751
# min               333.596667           0.000000         0.000000
# 25%              1651.583750           3.000000         4.000000
# 50%              3115.270833           6.000000         6.000000
# 75%              6034.156667           7.000000         7.000000
# max             14866.446670        1798.000000      1499.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count    26097.00000         26097.000000          25588.000000
# mean        67.38629            21.125915             26.136158
# std        442.41794            14.682490            183.381561
# min          1.00000            -5.000000              0.000000
# 25%          7.00000            10.000000              3.000000
# 50%         13.00000            18.000000              6.000000
# 75%         20.00000            28.000000              9.000000
# max       5788.00000            67.000000           2594.000000
#
#        Credit_Utilization_Ratio  Total_EMI_per_month
# count              26097.000000         26096.000000
# mean                  32.289132          1418.247110
# std                    5.137407          8403.663755
# min                   20.000000             0.000000
# 25%                   28.021807            30.338204
# 50%                   32.303684            68.486703
# 75%                   36.539271           165.165125
# max                   50.000000         82256.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26097 entries, 0 to 26096
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        26097 non-null  object
#  1   Customer_ID               26097 non-null  object
#  2   Month                     26097 non-null  object
#  3   Name                      23488 non-null  object
#  4   Age                       26097 non-null  object
#  5   SSN                       26097 non-null  object
#  6   Occupation                26097 non-null  object
#  7   Annual_Income             26097 non-null  object
#  8   Monthly_Inhand_Salary     22174 non-null  float64
#  9   Num_Bank_Accounts         26097 non-null  int64
#  10  Num_Credit_Card           26097 non-null  int64
#  11  Interest_Rate             26097 non-null  int64
#  12  Num_of_Loan               26097 non-null  object
#  13  Type_of_Loan              23129 non-null  object
#  14  Delay_from_due_date       26097 non-null  int64
#  15  Num_of_Delayed_Payment    24252 non-null  object
#  16  Changed_Credit_Limit      26097 non-null  object
#  17  Num_Credit_Inquiries      25588 non-null  float64
#  18  Credit_Mix                26097 non-null  object
#  19  Outstanding_Debt          26097 non-null  object
#  20  Credit_Utilization_Ratio  26097 non-null  float64
#  21  Credit_History_Age        23690 non-null  object
#  22  Payment_of_Min_Amount     26096 non-null  object
#  23  Total_EMI_per_month       26096 non-null  float64
#  24  Amount_invested_monthly   24951 non-null  object
#  25  Payment_Behaviour         26096 non-null  object
#  26  Monthly_Balance           25772 non-null  object
#  27  Credit_Score              26096 non-null  object
# dtypes: float64(4), int64(4), object(20)
# memory usage: 5.6+ MB

# %%
df.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        2609
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       3923
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                2968
# Delay_from_due_date            0
# Num_of_Delayed_Payment      1845
# Changed_Credit_Limit           0
# Num_Credit_Inquiries         509
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          2407
# Payment_of_Min_Amount          1
# Total_EMI_per_month            1
# Amount_invested_monthly     1146
# Payment_Behaviour              1
# Monthly_Balance              325
# Credit_Score                   1
# dtype: int64

# %%
df.drop(["ID","Customer_ID","Name","SSN","Type_of_Loan"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       3923
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      1845
# Changed_Credit_Limit           0
# Num_Credit_Inquiries         509
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          2407
# Payment_of_Min_Amount          1
# Total_EMI_per_month            1
# Amount_invested_monthly     1146
# Payment_Behaviour              1
# Monthly_Balance              325
# Credit_Score                   1
# dtype: int64

# %%
df.drop(columns='Payment_Behaviour',inplace=True)
df.head()
# Out:
#       Month   Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0   January    23  Scientist      19114.12            1824.843333
# 1  February    23  Scientist      19114.12                    NaN
# 2     March  -500  Scientist      19114.12                    NaN
# 3     April    23  Scientist      19114.12                    NaN
# 4       May    23  Scientist      19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                  3                4              3           4
# 1                  3                4              3           4
# 2                  3                4              3           4
# 3                  3                4              3           4
# 4                  3                4              3           4
#
#    Delay_from_due_date  ... Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 0                    3  ...                  4.0          _            809.98
# 1                   -1  ...                  4.0       Good            809.98
# 2                    3  ...                  4.0       Good            809.98
# 3                    5  ...                  4.0       Good            809.98
# 4                    6  ...                  4.0       Good            809.98
#
#   Credit_Utilization_Ratio     Credit_History_Age  Payment_of_Min_Amount  \
# 0                26.822620  22 Years and 1 Months                     No
# 1                31.944960                    NaN                     No
# 2                28.609352  22 Years and 3 Months                     No
# 3                31.377862  22 Years and 4 Months                     No
# 4                24.797347  22 Years and 5 Months                     No
#
#   Total_EMI_per_month Amount_invested_monthly  Monthly_Balance Credit_Score
# 0           49.574949             80.41529544      312.4940887         Good
# 1           49.574949             118.2802216      284.6291625         Good
# 2           49.574949             81.69952126      331.2098629         Good
# 3           49.574949             199.4580744      223.4513097         Good
# 4           49.574949             41.42015309       341.489231         Good
#
# [5 rows x 22 columns]

# %%
categorical_var = [feature for feature in df.columns if df[feature].dtypes == 'O']
numerical_var = [feature for feature in df.columns if feature not in categorical_var]

# %%
for feature in numerical_var:
    print(f"{feature}:")
    print(f"Number of unique values in the {feature}: {df[feature].nunique()}")
    print(f"Unique values: {df[feature].unique()}")
    print('\n')
# Out:
# Monthly_Inhand_Salary:
# Number of unique values in the Monthly_Inhand_Salary: 3452
# Unique values: [1824.843333         nan 3037.986667 ... 8718.4925   9430.56
#  2986.525   ]
#
#
# Num_Bank_Accounts:
# Number of unique values in the Num_Bank_Accounts: 302
# Unique values: [   3    2    1    7    4    0    8    5    6    9   10 1414 1231   67
#   572 1488   91  528 1647 1696 1338  649  889 1668  685  857  975 1496
#  1534 1620   37 1388 1429 1332 1588  120 1777 1096  803  494  744 1139
#   831 1613  741  121  665 1748 1644  823 1356 1651   87  711  450  210
#  1671 1722  648  672 1662 1495  510  666  429 1131 1434  980 1026  526
#   718 1300 1312 1315  501 1566  480 1042  322  628 1016  333 1265  791
#   427  563  905 1190 1036 1611   38  619  555 1769  280  752 1201  812
#  1487  222  212 1019 1222  610 1714 1308  525 1158 1115 1616  754 1601
#   797 1577  521  703  933  959  809 1089 1656 1113 1715  964 1533 1789
#   871  434 1295  565 1724  603  677  541  698 1101  464 1539 1462 1011
#  1257 1727   45  244 1266  897  535  484  331  675  826  946 1675  105
#  1.432e+03 1.970e+03 2.446e+03 1.758e+03 1.795e+03 1.066e+03 9.910e+02
#  2.324e+03 1.346e+03 5.810e+02 2.047e+03 1.370e+02 1.352e+03 2.261e+03
#  1.772e+03 1.668e+03 1.204e+03 1.601e+03 2.059e+03 1.099e+03 6.280e+02
#  5.760e+02 4.960e+02 8.160e+02 1.469e+03 6.300e+01 1.893e+03 2.060e+03
#  1.500e+02 1.345e+03 1.157e+03 3.370e+02 4.550e+02 8.530e+02 1.779e+03
#  2.323e+03 2.192e+03 1.433e+03]
#
#
# Credit_Utilization_Ratio:
# Number of unique values in the Credit_Utilization_Ratio: 26097
# Unique values: [26.82261962 31.94496006 28.60935202 ... 32.90893673 25.22572603
#  38.5365252 ]
#
#
# Total_EMI_per_month:
# Number of unique values in the Total_EMI_per_month: 3912
# Unique values: [ 49.57494921  18.81621457 246.9923195  ...  33.86127275  93.70923447
#           nan]

# %%
df.head()
# Out:
#       Month   Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0   January    23  Scientist      19114.12            1824.843333
# 1  February    23  Scientist      19114.12                    NaN
# 2     March  -500  Scientist      19114.12                    NaN
# 3     April    23  Scientist      19114.12                    NaN
# 4       May    23  Scientist      19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                  3                4              3           4
# 1                  3                4              3           4
# 2                  3                4              3           4
# 3                  3                4              3           4
# 4                  3                4              3           4
#
#    Delay_from_due_date  ... Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 0                    3  ...                  4.0          _            809.98
# 1                   -1  ...                  4.0       Good            809.98
# 2                    3  ...                  4.0       Good            809.98
# 3                    5  ...                  4.0       Good            809.98
# 4                    6  ...                  4.0       Good            809.98
#
#   Credit_Utilization_Ratio     Credit_History_Age  Payment_of_Min_Amount  \
# 0                26.822620  22 Years and 1 Months                     No
# 1                31.944960                    NaN                     No
# 2                28.609352  22 Years and 3 Months                     No
# 3                31.377862  22 Years and 4 Months                     No
# 4                24.797347  22 Years and 5 Months                     No
#
#   Total_EMI_per_month Amount_invested_monthly  Monthly_Balance Credit_Score
# 0           49.574949             80.41529544      312.4940887         Good
# 1           49.574949             118.2802216      284.6291625         Good
# 2           49.574949             81.69952126      331.2098629         Good
# 3           49.574949             199.4580744      223.4513097         Good
# 4           49.574949             41.42015309       341.489231         Good
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       3923
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      1845
# Changed_Credit_Limit           0
# Num_Credit_Inquiries         509
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          2407
# Payment_of_Min_Amount          1
# Total_EMI_per_month            1
# Amount_invested_monthly     1146
# Monthly_Balance              325
# Credit_Score                   1
# dtype: int64

# %%
df['Monthly_Inhand_Salary'].fillna(df['Monthly_Inhand_Salary'].mean(),inplace=True)
df['Num_of_Delayed_Payment']=pd.to_numeric(df['Num_of_Delayed_Payment'],errors='coerce')
df['Num_of_Delayed_Payment'].fillna(df['Num_of_Delayed_Payment'].mean(),inplace=True)
df['Amount_invested_monthly']=pd.to_numeric(df['Amount_invested_monthly'],errors='coerce')
df['Amount_invested_monthly'].fillna(df['Amount_invested_monthly'].mean(),inplace=True)
df['Num_Credit_Inquiries'].fillna(df['Num_Credit_Inquiries'].mean(),inplace=True)
df['Monthly_Balance']=pd.to_numeric(df['Monthly_Balance'],errors='coerce')
df['Monthly_Balance'].fillna(df['Monthly_Balance'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Delay_from_due_date            0
# Num_of_Delayed_Payment         0
# Changed_Credit_Limit           0
# Num_Credit_Inquiries           0
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          2407
# Payment_of_Min_Amount          1
# Total_EMI_per_month            1
# Amount_invested_monthly        0
# Monthly_Balance                0
# Credit_Score                   1
# dtype: int64

# %%
df['Credit_History_Age'] = df['Credit_History_Age'].str.extract(r'(\d+)')
df['Credit_History_Age']=pd.to_numeric(df['Credit_History_Age'],errors='coerce')
df['Credit_History_Age'].fillna(df['Credit_History_Age'].mean(),inplace=True)

# %%
df.drop(df[df["Occupation"]=='_______'].index,inplace=True)
df.drop(df[df["Credit_Mix"]=='_'].index,inplace=True)

# %%
df.isnull().sum()
# Out:
# Month                       0
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       1
# Total_EMI_per_month         1
# Amount_invested_monthly     0
# Monthly_Balance             0
# Credit_Score                1
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Month                       0
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
df['Age'] = df['Age'].replace('-500',np.nan)
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
df['Age'] = df['Age'].apply(lambda x: x if x<113 else np.nan)
age_mean=df["Age"].mean()
df["Age"].fillna(age_mean, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for feature in categorical_var:
    df[feature]=le.fit_transform(df[feature])

# %%
df['Delay_from_due_date']=df['Delay_from_due_date'].abs()
df.head()
# Out:
#    Month  Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 1      2    9          12           1424            4226.596994
# 2      6   20          12           1424            4226.596994
# 3      0    9          12           1424            4226.596994
# 4      7    9          12           1424            1824.843333
# 5      5    9          12           1424            4226.596994
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 1                  3                4              3           53
# 2                  3                4              3           53
# 3                  3                4              3           53
# 4                  3                4              3           53
# 5                  3                4              3           53
#
#    Delay_from_due_date  ...  Num_Credit_Inquiries  Credit_Mix  \
# 1                    1  ...                   4.0           1
# 2                    3  ...                   4.0           1
# 3                    5  ...                   4.0           1
# 4                    6  ...                   4.0           1
# 5                    8  ...                   4.0           1
#
#    Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 1              3144                 31.944960                  19
# 2              3144                 28.609352                  23
# 3              3144                 31.377862                  23
# 4              3144                 24.797347                  23
# 5              3144                 27.262259                  23
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 1                      1            49.574949                     8043
# 2                      1            49.574949                     5187
# 3                      1            49.574949                    12100
# 4                      1            49.574949                     1577
# 5                      1            49.574949                     3466
#
#    Monthly_Balance  Credit_Score
# 1             5907             0
# 2             9256             0
# 3             2075             0
# 4             9874             0
# 5             9813             0
#
# [5 rows x 22 columns]

# %%
corr=df.corr()
plt.figure(figsize=(20,15))
sns.heatmap(corr,annot=True,fmt=".2f",cmap="coolwarm")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

x=df.drop('Credit_Score',axis=1)
y=df['Credit_Score']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier()
}
acc=[]
for model_name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    acc.append(accuracy)
    print(f"{model_name} Accuracy: {accuracy}")
# Out:
# Logistic Regression Accuracy: 0.5312822275696115
# Decision Tree Accuracy: 0.6835682365073908
# Random Forest Accuracy: 0.7837744929529048
# Support Vector Machine Accuracy: 0.53540735647989
# K-Nearest Neighbors Accuracy: 0.5036094877964936

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=list(models.keys()),y=acc)
plt.show()
